# %%
class Polites(X, y, model):
    def _init_(X, y, model)
    self.X = X
    self.y = y 
    self.model = self.model
    
    def clean_data_tokenizer(self):
        
    def train_model(self):
        
    def

# %%
# %%file train_svm.py

import pandas as pd 
import os
os.chdir(r"/home/est_posgrado_enrique.santibanez/tesis/PolitiES/src")

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
from test_evaluation import *

var_predictions = ["gender", "profession", "ideology_binary", "ideology_multiclass"]
reviews_politica = pd.read_csv("../data/raw/development.csv")
reviews_politica.head()

# Create a TFIDF Vectorizer using sci-kit. With this, we are going to represent all texts
# as counts of the vocabulary. 
vectorizer = TfidfVectorizer (
  analyzer = 'word',
  min_df = .1,
  max_features = 5000,
  lowercase = True
) 

# Get the TF-IDF values from the training set
X_train = vectorizer.fit_transform (reviews_politica['tweet'])

# Get the TF-IDF values from the test set
# Note that we apply the TF-IDF learned from the training split 
X_test = vectorizer.transform (reviews_politica['tweet'])

# We are going to store a baseline per trait
baselines = {}
# As we observed, this task is about four traits: two demographic and two psychographic. Therefore, we are going to
# train different and separate models for each task
for label in var_predictions:

# Get a baseline classifier
baselines[label] = SVC()


# Train the baseline for this label
baselines[label].fit(X_train, reviews_politica[label])
    
test_evaluation(X_test, reviews_politica[var_predictions], baselines,
               "/home/est_posgrado_enrique.santibanez/tesis/PolitiES/model/results/prueba.txt")
# Out:
# Writing train_svm.py

# %% [markdown]
# ### methods DA

# %%
# noise_injection: action, aug_p (listo)
# replacing_synonym: aug_p (listo)
# expresion_regulares: 
# back_translate: idioma (listo)
# replacing_embeddings: Word2vec, Glove, Fassttext

# %% [markdown]
# ### Entrenamiento

# %%
import pandas as pd 
import numpy as np
import itertools

import os
os.chdir(r"/home/enrique/Documentos/AutoML_in_data_aumentation/taks/PolitiES/src/")

from general_functions import *


# global vars
path_train = "../data/raw/development.csv"
path_test = "../test/development_test.csv"
names_columns = ["name_taks", "model", "method_da", "lambda_hyper_1", "lambda_hyper_2", "preprocesamiento", "representation", 
                 "error_train_gender", "error_train_profession", "error_train_ideology_binary", "error_train_ideology_multiclass", "error_train",
                 "error_test_gender", "error_test_profession", "error_test_ideology_binary", "error_test_ideology_multiclass", "error_test"]
# Out:
# [nltk_data] Error loading punkt: <urlopen error [Errno -3] Temporary
# [nltk_data]     failure in name resolution>
# [nltk_data] Error loading stopwords: <urlopen error [Errno -3]
# [nltk_data]     Temporary failure in name resolution>

# %% [markdown]
# ### Without DA

# %%
train_test = format_data_origin(path_train, path_test)

error_train_test(df=train_test, path_errors="/home/enrique/Documentos/AutoML_in_data_aumentation/taks/PolitiES/model/results/errors/logistic_error.csv")
# Out:
# 0

# %%
train_test = format_data_origin(path_train, path_test)

error_train_test(df=train_test,  preprocess=["1"],
                 path_errors="/home/enrique/Documentos/AutoML_in_data_aumentation/taks/PolitiES/model/results/errors/logistic_error.csv")
# Out:
# 0

# %% [markdown]
# ### DA Noise Injection

# %%
error_train_test(df=train_test, method_da= ["noise_injection"], lambda_hyper=["delete", 0.3], preprocess=["1"],
                 path_errors="/home/enrique/Documentos/AutoML_in_data_aumentation/taks/PolitiES/model/results/errors/logistic_error.csv")
# Out:
# 0

# %%
train_test = format_data_origin(path_train, path_test)

error_train_test(df=train_test, method_da= ["noise_injection"], lambda_hyper=["delete", 0.3], preprocess=["-1"],
                 path_errors="/home/enrique/Documentos/AutoML_in_data_aumentation/taks/PolitiES/model/results/errors/logistic_error.csv")
# Out:
# 0

# %%
train_test = format_data_origin(path_train, path_test)

error_train_test(df=train_test, method_da= ["noise_injection"], lambda_hyper=['swap', 0.3], preprocess=["1"],
                 path_errors="/home/enrique/Documentos/AutoML_in_data_aumentation/taks/PolitiES/model/results/errors/logistic_error.csv")
# Out:
# 0

# %%
train_test = format_data_origin(path_train, path_test)

error_train_test(df=train_test, method_da= ["noise_injection"], lambda_hyper=['swap', 0.3], preprocess=["-1"],
                 path_errors="/home/enrique/Documentos/AutoML_in_data_aumentation/taks/PolitiES/model/results/errors/logistic_error.csv")
# Out:
# 0

# %% [markdown]
# ### Replace by synonym

# %%
train_test = format_data_origin(path_train, path_test)

error_train_test(df=train_test, method_da= ["replacing_synonym"], lambda_hyper=['-1', 0.5], preprocess=["1"],
                 path_errors="/home/enrique/Documentos/AutoML_in_data_aumentation/taks/PolitiES/model/results/errors/logistic_error.csv")
# Out:
# 0

# %%
train_test = format_data_origin(path_train, path_test)

error_train_test(df=train_test, method_da= ["replacing_synonym"], lambda_hyper=['-1', 0.5], preprocess=["-1"],
                 path_errors="/home/enrique/Documentos/AutoML_in_data_aumentation/taks/PolitiES/model/results/errors/logistic_error.csv")
# Out:
# 0

# %% [markdown]
# ### Back Translation

# %% [markdown]
# ### Errores

# %%
errores_finales = pd.read_csv("/home/enrique/Documentos/AutoML_in_data_aumentation/taks/PolitiES/model/results/errors/logistic_error.csv",
           index_col=False)

# %%
errores_finales.sort_values(by=["name_taks", "model", "method_da"])
# Out:
#    name_taks               model          method_da lambda_hyper_1  \
# 0   PolitiES  LogisticRegression                 -1             -1
# 1   PolitiES  LogisticRegression                 -1             -1
# 2   PolitiES  LogisticRegression                 -1             -1
# 3   PolitiES  LogisticRegression                 -1             -1
# 6   PolitiES  LogisticRegression                 -1             -1
# 4   PolitiES  LogisticRegression    noise_injection         delete
# 5   PolitiES  LogisticRegression    noise_injection         delete
# 7   PolitiES  LogisticRegression    noise_injection           swap
# 8   PolitiES  LogisticRegression    noise_injection           swap
# 9   PolitiES  LogisticRegression  replacing_synonym             -1
# 10  PolitiES  LogisticRegression  replacing_synonym             -1
# 11  PolitiES                 SVC                 -1             -1
# 12  PolitiES                 SVC                 -1             -1
# ...

# %%
var_interes_erro = ["name_taks", "model", "method_da", "lambda_hyper_1","lambda_hyper_2", "preprocesamiento", "error_train", "error_test"]

# %%
errors_finales_filtra=errores_finales.drop_duplicates().sort_values(by=["name_taks", "model", "method_da"])[var_interes_erro]

# %%
errors_finales_filtra
# Out:
#    name_taks               model          method_da lambda_hyper_1  \
# 0   PolitiES  LogisticRegression                 -1             -1
# 6   PolitiES  LogisticRegression                 -1             -1
# 4   PolitiES  LogisticRegression    noise_injection         delete
# 5   PolitiES  LogisticRegression    noise_injection         delete
# 7   PolitiES  LogisticRegression    noise_injection           swap
# 8   PolitiES  LogisticRegression    noise_injection           swap
# 9   PolitiES  LogisticRegression  replacing_synonym             -1
# 10  PolitiES  LogisticRegression  replacing_synonym             -1
# 11  PolitiES                 SVC                 -1             -1
# 13  PolitiES                 SVC                 -1             -1
# 14  PolitiES                 SVC    noise_injection         delete
# 15  PolitiES                 SVC    noise_injection         delete
# 16  PolitiES                 SVC    noise_injection           swap
# ...

# %%
errors_finales_filtra
# Out:
#    name_taks               model          method_da lambda_hyper_1  \
# 0   PolitiES  LogisticRegression                 -1             -1
# 6   PolitiES  LogisticRegression                 -1             -1
# 4   PolitiES  LogisticRegression    noise_injection         delete
# 5   PolitiES  LogisticRegression    noise_injection         delete
# 7   PolitiES  LogisticRegression    noise_injection           swap
# 8   PolitiES  LogisticRegression    noise_injection           swap
# 9   PolitiES  LogisticRegression  replacing_synonym             -1
# 10  PolitiES  LogisticRegression  replacing_synonym             -1
# 11  PolitiES                 SVC                 -1             -1
# 13  PolitiES                 SVC                 -1             -1
# 14  PolitiES                 SVC    noise_injection         delete
# 15  PolitiES                 SVC    noise_injection         delete
# 16  PolitiES                 SVC    noise_injection           swap
# ...

# %%
errors_finales_filtra[errors_finales_filtra.preprocesamiento==1]
# Out:
#    name_taks               model          method_da lambda_hyper_1  \
# 6   PolitiES  LogisticRegression                 -1             -1
# 4   PolitiES  LogisticRegression    noise_injection         delete
# 7   PolitiES  LogisticRegression    noise_injection           swap
# 9   PolitiES  LogisticRegression  replacing_synonym             -1
# 13  PolitiES                 SVC                 -1             -1
# 14  PolitiES                 SVC    noise_injection         delete
# 16  PolitiES                 SVC    noise_injection           swap
# 18  PolitiES                 SVC  replacing_synonym             -1
#
#     lambda_hyper_2  preprocesamiento  error_train  error_test
# 6             -1.0                 1     0.818381    0.529330
# 4              0.3                 1     0.820073    0.529330
# 7              0.3                 1     0.818864    0.529330
# 9              0.5                 1     0.817131    0.529330
# ...
